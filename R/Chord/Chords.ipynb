# %%
mat <- read.csv("../TopicOccurencesPerTestament.csv", header=FALSE, sep=",")
rownames(mat) =  paste0("Topic ", 1:10)
colnames(mat) = paste0("Topic ", 1:10)
mat
# Out:
#          Topic 1 Topic 2 Topic 3 Topic 4 Topic 5 Topic 6 Topic 7 Topic 8
# Topic 1  10       0       1       1       0       1       2       1
# Topic 2   0      10       2       2       2       3       0       0
# Topic 3   1       2      10       1       1       1       1       0
# Topic 4   1       2       1      10       1       0       0       1
# Topic 5   0       2       1       1      10       1       1       0
# Topic 6   1       3       1       0       1      10       0       0
# Topic 7   2       0       1       0       1       0      10       0
# Topic 8   1       0       0       1       0       0       0      10
# Topic 9   0       1       2       0       1       0       2       0
# Topic 10  0       0       0       0       0       0       0       0
#          Topic 9 Topic 10
# Topic 1   0       0
# Topic 2   1       0
# Topic 3   2       0
# Topic 4   0       0
# Topic 5   1       0
# Topic 6   0       0
# Topic 7   2       0
# Topic 8   0       0
# ...

# %%
df = data.frame(from = rep(rownames(mat), times = ncol(mat)),
    to = rep(colnames(mat), each = nrow(mat)),
    value = as.vector(mat),
    stringsAsFactors = FALSE)
# Out:
# Warning message in data.frame(from = rep(rownames(mat), times = ncol(mat)), to = rep(colnames(mat), :
# “row names were found from a short variable and have been discarded”

# %%
chordDiagram(mat)
# Out:
# Warning message in chordDiagram(mat):
# “It seems your input data is an adjacency matrix, maybe you need to convert it to 'matrix' explicitely.”
# plot without title
