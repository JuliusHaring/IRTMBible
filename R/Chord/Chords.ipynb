# %%
mat <- read.csv("../TopicOccurencesPerTestament.csv", header=FALSE, sep="")
rownames(mat) = paste0("Book ", 1:2)
colnames(mat) = paste0("Topic ", 1:10)
mat
# Out:
# Error in `.rowNamesDF<-`(x, value = value): invalid 'row.names' length
# Traceback:
#
# 1. `rownames<-`(`*tmp*`, value = c("Book 1", "Book 2"))
# 2. `row.names<-`(`*tmp*`, value = value)
# 3. `row.names<-.data.frame`(`*tmp*`, value = value)
# 4. `.rowNamesDF<-`(x, value = value)
# 5. stop("invalid 'row.names' length")

# %%
df = data.frame(from = rep(rownames(mat), times = ncol(mat)),
    to = rep(colnames(mat), each = nrow(mat)),
    value = as.vector(mat),
    stringsAsFactors = FALSE)

# %%
chordDiagram(mat)
# Out:
# plot without title
